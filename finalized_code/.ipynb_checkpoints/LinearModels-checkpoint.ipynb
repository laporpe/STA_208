# %% [markdown]
# # Linear Models

# %%
import pandas as pd
import numpy as np

# %%
clean = pd.read_csv("../data/RHoMIS_Full_Data.csv", engine = "python")
clean.head()
# Out:
#   ID_PROJ ID_COUNTRY  YEAR  ITERATION    SURVEY_ID              ID_HH  \
# 0     CW2         BF  2015          1  BF_CW2_2015  BF_2015_CW2_182_1
# 1     CW2         BF  2015          1  BF_CW2_2015    BF_2015_CW2_7_1
# 2     CW2         BF  2015          1  BF_CW2_2015   BF_2015_CW2_25_1
# 3     CW2         BF  2015          1  BF_CW2_2015   BF_2015_CW2_39_1
# 4     CW2         BF  2015          1  BF_CW2_2015   BF_2015_CW2_24_1
#
#    GPS_LAT  GPS_LON  GPS_ALT start_time_user  ... Additional_respondents  \
# 0      NaN      NaN      NaN              na  ...                     na
# 1      NaN      NaN      NaN              na  ...                     na
# 2      NaN      NaN      NaN              na  ...                     na
# 3      NaN      NaN      NaN              na  ...                     na
# 4      NaN      NaN      NaN              na  ...                     na
#
#   quality_rapport quality_reliability end_time_user endtime_auto  \
# ...

# %%
from Functions import Cleaning_Functions
fun = Cleaning_Functions()

# %%
market_data = fun.delete_id_columns(clean) #1
print("1")
#market_data, pred_market = fun.drop_response_rows_with_NAs(market_data, "Market_Orientation") #2
market_data = fun.replace_NAN_with_na(market_data) #3
print("3")
market_data = fun.entry_to_lowercase(market_data) #4
print("4")
market_data = fun.remove_underscores_spaces(market_data) #5
print("5")
market_data = fun.convert_to_categorical(market_data) #6
print("6")
market_data = fun.impute_data(market_data)
print("7")
# Out:
# 1
# 3
# 4
# 5

# %%
clean.loc[:, "Market_Orientation"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Market_Orientation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-9444c8fbc491> in <module>
# ...

# %%
from sklearn.model_selection import train_test_split

X_m = market_data.loc[:, market_data.columns != 'Market_Orientation']
y_m = market_data.loc[:, "Market_Orientation"]
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X,y,test_size = .3)

X_train_m, X_test_m= fun.impute_data(X_train_m, X_test_m)

X_train_m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Market_Orientation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-37b060ea737a> in <module>
#       2
# ...
